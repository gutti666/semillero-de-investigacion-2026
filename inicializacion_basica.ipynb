# %% [markdown]
# # Notebook de Inicialización Básica
# ## Semillero de Investigación 2026
#
# Este notebook contiene la configuración básica para proyectos de ciencia de datos y machine learning.

# %% [markdown]
# ## 1. Importación de Librerías Básicas

# %%
# Librerías para manejo de datos
import pandas as pd
import numpy as np

# Librerías para visualización
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración de warnings
import warnings
warnings.filterwarnings('ignore')

print("Librerías importadas exitosamente")

# %% [markdown]
# ## 2. Configuración de Visualización

# %%
# Configuración de matplotlib
# %matplotlib inline
plt.style.use('seaborn-v0_8-darkgrid')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 12

# Configuración de seaborn
sns.set_palette('husl')

print("Configuración de visualización aplicada")

# %% [markdown]
# ## 3. Configuración de Pandas

# %%
# Opciones de visualización de pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

print("Configuración de pandas aplicada")

# %% [markdown]
# ## 4. Verificación de Versiones

# %%
# Verificar versiones de las librerías
import matplotlib
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Matplotlib version: {matplotlib.__version__}")
print(f"Seaborn version: {sns.__version__}")

# %% [markdown]
# ## 5. Ejemplo Básico: Cargar y Explorar Datos

# %%
# Ejemplo: Crear un DataFrame de ejemplo
data = {
    'nombre': ['Ana', 'Carlos', 'María', 'Juan', 'Lucía'],
    'edad': [25, 30, 28, 35, 27],
    'ciudad': ['Bogotá', 'Medellín', 'Cali', 'Barranquilla', 'Cartagena'],
    'puntaje': [85.5, 92.3, 78.9, 88.1, 95.7]
}

df = pd.DataFrame(data)
print("DataFrame de ejemplo:")
display(df)

# %%
# Estadísticas descriptivas
print("\nEstadísticas descriptivas:")
display(df.describe())

# %%
# Visualización de ejemplo
plt.figure(figsize=(10, 5))
plt.bar(df['nombre'], df['puntaje'], color='skyblue')
plt.xlabel('Nombre')
plt.ylabel('Puntaje')
plt.title('Puntajes por Persona')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Funciones Útiles

# %%
def cargar_datos(ruta_archivo):
    """
    Carga datos desde un archivo CSV.
    
    Parámetros:
    ruta_archivo (str): Ruta del archivo CSV
    
    Retorna:
    DataFrame: Datos cargados
    """
    try:
        df = pd.read_csv(ruta_archivo)
        print(f"Datos cargados exitosamente. Shape: {df.shape}")
        return df
    except Exception as e:
        print(f"Error al cargar datos: {e}")
        return None

def analisis_inicial(df):
    """
    Realiza un análisis inicial del DataFrame.
    
    Parámetros:
    df (DataFrame): DataFrame a analizar
    """
    print("=" * 50)
    print("ANÁLISIS INICIAL DE DATOS")
    print("=" * 50)
    print(f"\nDimensiones: {df.shape}")
    print(f"\nColumnas: {list(df.columns)}")
    print(f"\nTipos de datos:")
    print(df.dtypes)
    print(f"\nValores nulos:")
    print(df.isnull().sum())
    print(f"\nPrimeras 5 filas:")
    display(df.head())

print("Funciones útiles definidas")

# %% [markdown]
# ## 7. Espacio de Trabajo
#
# Utiliza las celdas siguientes para tu análisis:

# %%
# Tu código aquí
